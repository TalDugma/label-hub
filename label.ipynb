# %%
# use reload
# %load_ext autoreload
# %autoreload 2

# %%
# Enable interactive widgets
# %matplotlib widget 
from main import run_app
# specific configuration
checkpoint = "/Users/taldugma/sam2/checkpoints/sam2.1_hiera_tiny.pt"
cfg = "configs/sam2.1/sam2.1_hiera_t.yaml"

# DIRECT VIDEO PATH
video_path = "/Users/taldugma/Downloads/test.mp4" 
# Run the app
app = run_app(video_path, checkpoint, cfg)
# Out:
# 2026-01-19 22:25:10.662 | INFO     | utils:extract_video_frames:97 - Extracting frames from /Users/taldugma/Downloads/test.mp4 to /Users/taldugma/Downloads/test_frames...
# Preparing frames in /Users/taldugma/Downloads/test_frames...
# 2026-01-19 22:25:13.543 | INFO     | core:init_sam_model:66 - loaded model checkpoint /Users/taldugma/sam2/checkpoints/sam2.1_hiera_tiny.pt on cpu
# 2026-01-19 22:25:13.578 | INFO     | main:load_sequence:105 - Loaded 5 images from /Users/taldugma/Downloads/test_frames
# frame loading (JPEG): 100%|██████████| 5/5 [00:00<00:00, 77.19it/s]
# 2026-01-19 22:25:23.094 | INFO     | core:get_sam_features:115 - SAM features extracted.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
