# %%
# use reload
# %load_ext autoreload
# %autoreload 2
from core import init_model

# %%
# specific configuration
checkpoint = "/Users/taldugma/sam2/checkpoints/sam2.1_hiera_tiny.pt"
cfg = "configs/sam2.1/sam2.1_hiera_t.yaml"
model = init_model(checkpoint, cfg, device="cpu")
# Out:
# 2026-01-20 17:42:48.270 | INFO     | core:init_model:179 - Initializing SAM2Worker via Proxy on cpu...

# %%
# Enable interactive widgets
# %matplotlib widget 
from main import run_app


# DIRECT VIDEO PATH
video_path = "/Users/taldugma/Downloads/B7.mp4" 

# Run the app
app = run_app(video_path, model, log_file="my_app.log", start_frame=0, step=1, end_frame=6)
# Out:
# 2026-01-20 17:42:49.159 | INFO     | core:sam2_worker_loop:29 - Worker: Model loaded on cpu
# frame loading (JPEG): 100%|██████████| 6/6 [00:00<00:00, 86.92it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
